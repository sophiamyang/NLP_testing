# %% [markdown]
# # Running checklist test suite for SQuAD
# source: code from https://github.com/marcotcr/checklist/blob/115f123de47ab015b2c3a6baebaffb40bab80c9f/notebooks/tutorials/5.%20Testing%20transformer%20pipelines.ipynb with minor changes

# %%
# %load_ext autoreload
# %autoreload 2

import checklist
import spacy
import itertools

import checklist.editor
import checklist.text_generation
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect
from checklist.test_suite import TestSuite
import numpy as np
import spacy
from checklist.perturb import Perturb
import datasets
from transformers import AutoTokenizer, AutoModelForSequenceClassification, \
    AutoModelForQuestionAnswering, Trainer, TrainingArguments, HfArgumentParser
from transformers import pipeline

# %%
model_name = "trained_model_squad1/"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

model = pipeline('question-answering', model=model, tokenizer=tokenizer)

# %%
suite_path = 'squad_suite.pkl'
suite = TestSuite.from_file(suite_path)

# %%
def predconfs(context_question_pairs):
    preds = []
    confs = []
    for c, q in context_question_pairs:
        try:
            p = model(question=q, context=c, truncation=True, )
        except:
            print('Failed', q)
            preds.append(' ')
            confs.append(1)
        preds.append(p['answer'])
        confs.append(p['score'])
    return preds, np.array(confs)

# %%
suite.run(predconfs, n=100, overwrite=True)
# Out:
# Running A is COMP than B. Who is more COMP?
# Predicting 100 examples
# /opt/anaconda3/envs/nlp/lib/python3.9/site-packages/transformers/pipelines/question_answering.py:316: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   fw_args = {k: torch.tensor(v, device=self.device) for (k, v) in fw_args.items()}
# Running A is COMP than B. Who is less COMP?
# Predicting 100 examples
# Running Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Predicting 1200 examples
# Running size, shape, age, color
# Predicting 400 examples
# Running Profession vs nationality
# Predicting 1000 examples
# Running Animal vs Vehicle
# Predicting 400 examples
# Running Animal vs Vehicle v2
# Predicting 400 examples
# Running Synonyms
# Predicting 400 examples
# Running A is COMP than B. Who is antonym(COMP)? B
# Predicting 400 examples
# Running A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Predicting 1600 examples
# Running Question typo
# Predicting 200 examples
# Running Question contractions
# Predicting 200 examples
# Running Add random sentence to context
# Predicting 300 examples
# Running Change name everywhere
# Predicting 1100 examples
# Running Change location everywhere
# Predicting 1100 examples
# Running There was a change in profession
# Predicting 200 examples
# Running Understanding before / after -> first / last.
# Predicting 400 examples
# Running Negation in context, may or may not be in question
# Predicting 400 examples
# Running Negation in question only.
# Predicting 800 examples
# Running M/F failure rates should be similar for different professions
# Predicting 100 examples
# Running Basic coref, he / she
# Predicting 800 examples
# Running Basic coref, his / her
# Predicting 200 examples
# Running Former / Latter
# Predicting 400 examples
# Running Agent / object distinction
# Predicting 400 examples
# Running Agent / object distinction with 3 agents
# Predicting 1600 examples

# %%
def format_squad_with_context(x, pred, conf, label=None, *args, **kwargs):
    c, q = x
    ret = 'C: %s\nQ: %s\n' % (c, q)
    if label is not None:
        ret += 'A: %s\n' % label
    ret += 'P: %s\n' % pred
    return ret

# %%
suite.summary(format_example_fn=format_squad_with_context)
# Out:
# Vocabulary
#
# A is COMP than B. Who is more COMP?
# Test cases:      499
# Test cases run:  100
# Fails (rate):    0 (0.0%)
#
#
# A is COMP than B. Who is less COMP?
# Test cases:      497
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Frank is cleaner than Charlotte.
# Q: Who is less clean?
# A: Charlotte
# P: Frank
#
# ----
# C: Tony is richer than Pamela.
# Q: Who is less rich?
# A: Pamela
# P: Tony
#
# ----
# C: Nancy is taller than Susan.
# Q: Who is less tall?
# A: Susan
# P: Nancy
#
# ----
#
#
# Intensifiers (very, super, extremely) and reducers (somewhat, kinda, etc)?
# Test cases:      498
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Joseph is highly upbeat about the project. Martin is upbeat about the project.
# Q: Who is least upbeat about the project?
# A: Martin
# P: Joseph
#
# C: Martin is upbeat about the project. Joseph is highly upbeat about the project.
# Q: Who is least upbeat about the project?
# A: Martin
# P: Joseph
#
# C: Joseph is highly upbeat about the project. Martin is mildly upbeat about the project.
# Q: Who is least upbeat about the project?
# A: Martin
# P: Joseph
#
#
# ----
# C: Philip is serious about the project. Elaine is slightly serious about the project.
# Q: Who is least serious about the project?
# A: Elaine
# P: Philip
#
# C: Philip is extremely serious about the project. Elaine is slightly serious about the project.
# Q: Who is least serious about the project?
# A: Elaine
# P: Philip
#
# C: Elaine is slightly serious about the project. Philip is extremely serious about the project.
# Q: Who is least serious about the project?
# A: Elaine
# P: Philip
#
#
# ----
# C: Bob is skeptical about the project. Jimmy is slightly skeptical about the project.
# Q: Who is least skeptical about the project?
# A: Jimmy
# P: Bob
#
# C: Bob is very skeptical about the project. Jimmy is slightly skeptical about the project.
# Q: Who is least skeptical about the project?
# A: Jimmy
# P: Bob
#
# C: Jimmy is slightly skeptical about the project. Bob is skeptical about the project.
# Q: Who is least skeptical about the project?
# A: Jimmy
# P: Bob
#
#
# ----
#
#
#
#
# Taxonomy
#
# size, shape, age, color
# Test cases:      500
# Test cases run:  100
# Fails (rate):    92 (92.0%)
#
# Example fails:
# C: There is a sculpture in the room. The sculpture is triangular and yellow.
# Q: What shape is the sculpture?
# A: triangular
# P: triangular and yellow
#
# C: There is a triangular yellow sculpture in the room.
# Q: What shape is the sculpture?
# A: triangular
# P: triangular yellow
#
#
# ----
# C: There is a clock in the room. The clock is enormous and yellow.
# Q: What size is the clock?
# A: enormous
# P: enormous and yellow
#
# C: There is an enormous yellow clock in the room.
# Q: What size is the clock?
# A: enormous
# P: enormous yellow
#
#
# ----
# C: There is a tiny pink object in the room.
# Q: What size is the object?
# A: tiny
# P: pink
#
# C: There is an object in the room. The object is tiny and pink.
# Q: What size is the object?
# A: tiny
# P: tiny and pink
#
#
# ----
#
#
# Profession vs nationality
# Test cases:      500
# Test cases run:  100
# Fails (rate):    60 (60.0%)
#
# Example fails:
# C: Dan is a Bangladeshi attorney.
# Q: What is Dan's job?
# A: attorney
# P: Bangladeshi attorney
#
#
# ----
# C: Elizabeth is a Brazilian author.
# Q: What is Elizabeth's job?
# A: author
# P: Brazilian author
#
# C: Elizabeth is an author and Brazilian.
# Q: What is Elizabeth's job?
# A: author
# P: author and Brazilian
#
#
# ----
# C: Frederick is an Indian artist.
# Q: What is Frederick's job?
# A: artist
# P: Indian artist
#
#
# ----
#
#
# Animal vs Vehicle
# Test cases:      500
# Test cases run:  100
# Fails (rate):    54 (54.0%)
#
# Example fails:
# C: Sally has a cow and a car.
# Q: What vehicle does Sally have?
# A: car
# P: a cow
#
#
# ----
# C: Frances has an iguana and a firetruck.
# Q: What vehicle does Frances have?
# A: firetruck
# P: iguana
#
# C: Frances has a firetruck and an iguana.
# Q: What animal does Frances have?
# A: iguana
# P: firetruck and an iguana
#
# C: Frances has a firetruck and an iguana.
# Q: What vehicle does Frances have?
# A: firetruck
# P: firetruck and an iguana
#
#
# ----
# C: Thomas has a bull and a bike.
# Q: What vehicle does Thomas have?
# A: bike
# P: bull and a bike
#
#
# ----
#
#
# Animal vs Vehicle v2
# Test cases:      498
# Test cases run:  100
# Fails (rate):    26 (26.0%)
#
# Example fails:
# C: Mike bought a duck. Christopher bought a firetruck.
# Q: Who bought a vehicle?
# A: Christopher
# P: Mike
#
#
# ----
# C: Frances bought a SUV. Matt bought a serpent.
# Q: Who bought an animal?
# A: Matt
# P: Frances
#
#
# ----
# C: Jim bought a cat. Lauren bought a firetruck.
# Q: Who bought a vehicle?
# A: Lauren
# P: Jim
#
#
# ----
#
#
# Synonyms
# Test cases:      444
# Test cases run:  100
# Fails (rate):    6 (6.0%)
#
# Example fails:
# C: Rose is very religious. Kenneth is very thankful.
# Q: Who is spiritual?
# A: Rose
# P: Kenneth
#
#
# ----
# C: Steven is very vocal. Chris is very courageous.
# Q: Who is outspoken?
# A: Steven
# P: Chris
#
#
# ----
# C: Patrick is very happy. Walter is very angry.
# Q: Who is joyful?
# A: Patrick
# P: Walter
#
#
# ----
#
#
# A is COMP than B. Who is antonym(COMP)? B
# Test cases:      498
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Benjamin is quieter than Rachel.
# Q: Who is louder?
# A: Rachel
# P: Benjamin
#
# C: Rachel is louder than Benjamin.
# Q: Who is quieter?
# A: Benjamin
# P: Rachel
#
#
# ----
# C: Donald is darker than Sara.
# Q: Who is lighter?
# A: Sara
# P: Donald
#
# C: Sara is lighter than Donald.
# Q: Who is darker?
# A: Donald
# P: Sara
#
#
# ----
# C: Kelly is louder than Pamela.
# Q: Who is quieter?
# A: Pamela
# P: Kelly
#
# C: Pamela is quieter than Kelly.
# Q: Who is louder?
# A: Kelly
# P: Pamela
#
#
# ----
#
#
# A is more X than B. Who is more antonym(X)? B. Who is less X? B. Who is more X? A. Who is less antonym(X)? A.
# Test cases:      498
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Larry is more unhappy than Julie.
# Q: Who is less unhappy?
# A: Julie
# P: Larry
#
# C: Julie is more happy than Larry.
# Q: Who is less happy?
# A: Larry
# P: Julie
#
# C: Larry is less happy than Julie.
# Q: Who is less unhappy?
# A: Julie
# P: Larry
#
#
# ----
# C: Catherine is less invisible than Lynn.
# Q: Who is more invisible?
# A: Lynn
# P: Catherine
#
# C: Catherine is more visible than Lynn.
# Q: Who is less visible?
# A: Lynn
# P: Catherine
#
# C: Lynn is more invisible than Catherine.
# Q: Who is less invisible?
# A: Catherine
# P: Lynn
#
#
# ----
# C: Frederick is more active than Tony.
# Q: Who is less active?
# A: Tony
# P: Frederick
#
# C: Frederick is less passive than Tony.
# Q: Who is less active?
# A: Tony
# P: Frederick
#
# C: Frederick is more active than Tony.
# Q: Who is more passive?
# A: Tony
# P: Frederick
#
#
# ----
#
#
#
#
# Robustness
#
# Question typo
# Test cases:      500
# Test cases run:  100
# Fails (rate):    18 (18.0%)
#
# Example fails:
# C: Thai alphabet support has been criticized for its ordering of Thai characters. The vowels เ, แ, โ, ใ, ไ that are written to the left of the preceding consonant are in visual order instead of phonetic order, unlike the Unicode representations of other Indic scripts. This complication is due to Unicode inheriting the Thai Industrial Standard 620, which worked in the same way, and was the way in which Thai had always been written on keyboards. This ordering problem complicates the Unicode collation process slightly, requiring table lookups to reorder Thai characters for collation. Even if Unicode had adopted encoding according to spoken order, it would still be problematic to collate words in dictionary order. E.g., the word แสดง  [sa dɛːŋ] "perform" starts with a consonant cluster "สด" (with an inherent vowel for the consonant "ส"), the vowel แ-, in spoken order would come after the ด, but in a dictionary, the word is collated as it is written, with the vowel following the ส.
# Q: Why has Thai alphabet support been criticized?
# P: ordering of Thai characters
#
# C: Thai alphabet support has been criticized for its ordering of Thai characters. The vowels เ, แ, โ, ใ, ไ that are written to the left of the preceding consonant are in visual order instead of phonetic order, unlike the Unicode representations of other Indic scripts. This complication is due to Unicode inheriting the Thai Industrial Standard 620, which worked in the same way, and was the way in which Thai had always been written on keyboards. This ordering problem complicates the Unicode collation process slightly, requiring table lookups to reorder Thai characters for collation. Even if Unicode had adopted encoding according to spoken order, it would still be problematic to collate words in dictionary order. E.g., the word แสดง  [sa dɛːŋ] "perform" starts with a consonant cluster "สด" (with an inherent vowel for the consonant "ส"), the vowel แ-, in spoken order would come after the ด, but in a dictionary, the word is collated as it is written, with the vowel following the ส.
# Q: Why has Thai alphabet supportb een criticized?
# P: its ordering of Thai characters
#
#
# ----
# C: Most of the Estonian Defence Forces surrendered according to the orders of the Estonian government, believing that resistance was useless and were disarmed by the Red Army. Only the Estonian Independent Signal Battalion showed resistance to Red Army and Communist militia "People's Self-Defence" units in front of the XXI Grammar School in Tallinn on 21 June. As the Red Army brought in additional reinforcements supported by six armoured fighting vehicles, the battle lasted several hours until sundown. Finally the military resistance was ended with negotiations and the Independent Signal Battalion surrendered and was disarmed. There were two dead Estonian servicemen, Aleksei Männikus and Johannes Mandre, and several wounded on the Estonian side and about ten killed and more wounded on the Soviet side.
# Q: Who commanded the defense of the Estonia to surrender?
# P: the Estonian government
#
# C: Most of the Estonian Defence Forces surrendered according to the orders of the Estonian government, believing that resistance was useless and were disarmed by the Red Army. Only the Estonian Independent Signal Battalion showed resistance to Red Army and Communist militia "People's Self-Defence" units in front of the XXI Grammar School in Tallinn on 21 June. As the Red Army brought in additional reinforcements supported by six armoured fighting vehicles, the battle lasted several hours until sundown. Finally the military resistance was ended with negotiations and the Independent Signal Battalion surrendered and was disarmed. There were two dead Estonian servicemen, Aleksei Männikus and Johannes Mandre, and several wounded on the Estonian side and about ten killed and more wounded on the Soviet side.
# Q: Who cmomanded the defense of the Estonia to surrender?
# P: the orders of the Estonian government
#
#
# ----
# C: Sometimes it is desired to bring a database back to a previous state (for many reasons, e.g., cases when the database is found corrupted due to a software error, or if it has been updated with erroneous data). To achieve this a backup operation is done occasionally or continuously, where each desired database state (i.e., the values of its data and their embedding in database's data structures) is kept within dedicated backup files (many techniques exist to do this effectively). When this state is needed, i.e., when it is decided by a database administrator to bring the database back to this state (e.g., by specifying this state by a desired point in time when the database was in this state), these files are utilized to restore that state.
# Q: What parameter is requiret to restore a database?
# P: a desired point in time when the database was in this state
#
# C: Sometimes it is desired to bring a database back to a previous state (for many reasons, e.g., cases when the database is found corrupted due to a software error, or if it has been updated with erroneous data). To achieve this a backup operation is done occasionally or continuously, where each desired database state (i.e., the values of its data and their embedding in database's data structures) is kept within dedicated backup files (many techniques exist to do this effectively). When this state is needed, i.e., when it is decided by a database administrator to bring the database back to this state (e.g., by specifying this state by a desired point in time when the database was in this state), these files are utilized to restore that state.
# Q: What parameter is requiret to restore a adtabase?
# P: by a desired point in time when the database was in this state
#
#
# ----
#
#
# Question contractions
# Test cases:      500
# Test cases run:  100
# Fails (rate):    2 (2.0%)
#
# Example fails:
# C: Summers are generally warm and sometimes hot. London's average July high is 24 °C (75.2 °F). On average London will see 31 days above 25 °C (77.0 °F) each year, and 4.2 days above 30.0 °C (86.0 °F) every year. During the 2003 European heat wave there were 14 consecutive days above 30 °C (86.0 °F) and 2 consecutive days where temperatures reached 38 °C (100.4 °F), leading to hundreds of heat related deaths. Winters are generally cool and damp with little temperature variation. Snowfall does occur from time to time, and can cause travel disruption when this happens. Spring and autumn are mixed seasons and can be pleasant. As a large city, London has a considerable urban heat island effect, making the centre of London at times 5 °C (9 °F) warmer than the suburbs and outskirts. The effect of this can be seen below when comparing London Heathrow, 15 miles west of London, with the London Weather Centre, in the city centre.
# Q: What is London's average high temperature in July?
# P: 24 °C (75.2 °F)
#
# C: Summers are generally warm and sometimes hot. London's average July high is 24 °C (75.2 °F). On average London will see 31 days above 25 °C (77.0 °F) each year, and 4.2 days above 30.0 °C (86.0 °F) every year. During the 2003 European heat wave there were 14 consecutive days above 30 °C (86.0 °F) and 2 consecutive days where temperatures reached 38 °C (100.4 °F), leading to hundreds of heat related deaths. Winters are generally cool and damp with little temperature variation. Snowfall does occur from time to time, and can cause travel disruption when this happens. Spring and autumn are mixed seasons and can be pleasant. As a large city, London has a considerable urban heat island effect, making the centre of London at times 5 °C (9 °F) warmer than the suburbs and outskirts. The effect of this can be seen below when comparing London Heathrow, 15 miles west of London, with the London Weather Centre, in the city centre.
# Q: What's London's average high temperature in July?
# P: 24 °C
#
#
# ----
# C: The history of science is the study of the development of science and scientific knowledge, including both the natural sciences and social sciences. (The history of the arts and humanities is termed as the history of scholarship.) Science is a body of empirical, theoretical, and practical knowledge about the natural world, produced by scientists who emphasize the observation, explanation, and prediction of real world phenomena. Historiography of science, in contrast, often draws on the historical methods of both intellectual history and social history.
# Q: What are natural and social sciences a subcategory of?
# P: science and scientific knowledge
#
# C: The history of science is the study of the development of science and scientific knowledge, including both the natural sciences and social sciences. (The history of the arts and humanities is termed as the history of scholarship.) Science is a body of empirical, theoretical, and practical knowledge about the natural world, produced by scientists who emphasize the observation, explanation, and prediction of real world phenomena. Historiography of science, in contrast, often draws on the historical methods of both intellectual history and social history.
# Q: What're natural and social sciences a subcategory of?
# P: The history of science
#
#
# ----
#
#
# Add random sentence to context
# Test cases:      500
# Test cases run:  100
# Fails (rate):    12 (12.0%)
#
# Example fails:
# C: On July 25, 2015, the 18th and 19th satellites were successfully launched from the Xichang Satellite Launch Center, marking the first time for China to launch two satellites at once on top of a Long March 3B/Expedition-1 carrier rocket. The Expedition-1 is an independent upper stage capable of delivering one or more spacecraft into different orbits.
# Q: What were the 18th and 19th satellites for the BeiDou system launched with?
# P: Expedition-1 carrier rocket
#
# C: Perhaps the most important expression of Islamic art is architecture, particularly that of the mosque. On July 25, 2015, the 18th and 19th satellites were successfully launched from the Xichang Satellite Launch Center, marking the first time for China to launch two satellites at once on top of a Long March 3B/Expedition-1 carrier rocket. The Expedition-1 is an independent upper stage capable of delivering one or more spacecraft into different orbits.
# Q: What were the 18th and 19th satellites for the BeiDou system launched with?
# P: a Long March 3B/Expedition-1 carrier rocket
#
#
# ----
# C: To finance state government operations, Alaska depends primarily on petroleum revenues and federal subsidies. This allows it to have the lowest individual tax burden in the United States. It is one of five states with no state sales tax, one of seven states that do not levy an individual income tax, and one of the two states that has neither. The Department of Revenue Tax Division reports regularly on the state's revenue sources. The Department also issues an annual summary of its operations, including new state laws that directly affect the tax division.
# Q: How does Alaska finance its state government operations?
# P: depends primarily on petroleum revenues and federal subsidies
#
# C: According to Joël Bellassen (1989), the most complex Chinese character is /𪚥 (U+2A6A5) zhé  listen (help·info), meaning "verbose" and containing sixty-four strokes; this character fell from use around the 5th century. To finance state government operations, Alaska depends primarily on petroleum revenues and federal subsidies. This allows it to have the lowest individual tax burden in the United States. It is one of five states with no state sales tax, one of seven states that do not levy an individual income tax, and one of the two states that has neither. The Department of Revenue Tax Division reports regularly on the state's revenue sources. The Department also issues an annual summary of its operations, including new state laws that directly affect the tax division.
# Q: How does Alaska finance its state government operations?
# P: petroleum revenues and federal subsidies
#
# C: To finance state government operations, Alaska depends primarily on petroleum revenues and federal subsidies. This allows it to have the lowest individual tax burden in the United States. It is one of five states with no state sales tax, one of seven states that do not levy an individual income tax, and one of the two states that has neither. The Department of Revenue Tax Division reports regularly on the state's revenue sources. The Department also issues an annual summary of its operations, including new state laws that directly affect the tax division.According to Joël Bellassen (1989), the most complex Chinese character is /𪚥 (U+2A6A5) zhé  listen (help·info), meaning "verbose" and containing sixty-four strokes; this character fell from use around the 5th century.
# Q: How does Alaska finance its state government operations?
# P: petroleum revenues and federal subsidies
#
#
# ----
# C: USB mice and keyboards can usually be used with older computers that have PS/2 connectors with the aid of a small USB-to-PS/2 adapter. For mice and keyboards with dual-protocol support, an adaptor that contains no logic circuitry may be used: the hardware in the USB keyboard or mouse is designed to detect whether it is connected to a USB or PS/2 port, and communicate using the appropriate protocol. Converters also exist that connect PS/2 keyboards and mice (usually one of each) to a USB port. These devices present two HID endpoints to the system and use a microcontroller to perform bidirectional data translation between the two standards.
# Q: USB keyboards and mice may communicate using what?
# P: the appropriate protocol
#
# C: Impermanence (Pāli: anicca) expresses the Buddhist notion that all compounded or conditioned phenomena (all things and experiences) are inconstant, unsteady, and impermanent. USB mice and keyboards can usually be used with older computers that have PS/2 connectors with the aid of a small USB-to-PS/2 adapter. For mice and keyboards with dual-protocol support, an adaptor that contains no logic circuitry may be used: the hardware in the USB keyboard or mouse is designed to detect whether it is connected to a USB or PS/2 port, and communicate using the appropriate protocol. Converters also exist that connect PS/2 keyboards and mice (usually one of each) to a USB port. These devices present two HID endpoints to the system and use a microcontroller to perform bidirectional data translation between the two standards.
# Q: USB keyboards and mice may communicate using what?
# P: appropriate protocol
#
#
# ----
#
#
#
#
# NER
#
# Change name everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    9 (9.0%)
#
# Example fails:
# C: Whitehead and Russell had thought originally that Principia Mathematica would take a year to complete; it ended up taking them ten years. To add insult to injury, when it came time for publication, the three-volume work was so massive (more than 2,000 pages) and its audience so narrow (professional mathematicians) that it was initially published at a loss of 600 pounds, 300 of which was paid by Cambridge University Press, 200 by the Royal Society of London, and 50 apiece by Whitehead and Russell themselves. Despite the initial loss, today there is likely no major academic library in the world which does not hold a copy of Principia Mathematica.
# Q: How long did Whitehead and Russell think it would take them to complete Principia Mathematica?
# P: a year
#
# C: Whitehead and Adam had thought originally that Principia Mathematica would take a year to complete; it ended up taking them ten years. To add insult to injury, when it came time for publication, the three-volume work was so massive (more than 2,000 pages) and its audience so narrow (professional mathematicians) that it was initially published at a loss of 600 pounds, 300 of which was paid by Cambridge University Press, 200 by the Royal Society of London, and 50 apiece by Whitehead and Adam themselves. Despite the initial loss, today there is likely no major academic library in the world which does not hold a copy of Principia Mathematica.
# Q: How long did Whitehead and Adam think it would take them to complete Principia Mathematica?
# P: ten years
#
# C: Whitehead and Luke had thought originally that Principia Mathematica would take a year to complete; it ended up taking them ten years. To add insult to injury, when it came time for publication, the three-volume work was so massive (more than 2,000 pages) and its audience so narrow (professional mathematicians) that it was initially published at a loss of 600 pounds, 300 of which was paid by Cambridge University Press, 200 by the Royal Society of London, and 50 apiece by Whitehead and Luke themselves. Despite the initial loss, today there is likely no major academic library in the world which does not hold a copy of Principia Mathematica.
# Q: How long did Whitehead and Luke think it would take them to complete Principia Mathematica?
# P: ten years
#
#
# ----
# C: In December, Beyoncé along with a variety of other celebrities teamed up and produced a video campaign for "Demand A Plan", a bipartisan effort by a group of 950 US mayors and others designed to influence the federal government into rethinking its gun control laws, following the Sandy Hook Elementary School shooting. Beyoncé became an ambassador for the 2012 World Humanitarian Day campaign donating her song "I Was Here" and its music video, shot in the UN, to the campaign. In 2013, it was announced that Beyoncé would work with Salma Hayek and Frida Giannini on a Gucci "Chime for Change" campaign that aims to spread female empowerment. The campaign, which aired on February 28, was set to her new music. A concert for the cause took place on June 1, 2013 in London and included other acts like Ellie Goulding, Florence and the Machine, and Rita Ora. In advance of the concert, she appeared in a campaign video released on 15 May 2013, where she, along with Cameron Diaz, John Legend and Kylie Minogue, described inspiration from their mothers, while a number of other artists celebrated personal inspiration from other women, leading to a call for submission of photos of women of viewers' inspiration from which a selection was shown at the concert. Beyoncé said about her mother Tina Knowles that her gift was "finding the best qualities in every human being." With help of the crowdfunding platform Catapult, visitors of the concert could choose between several projects promoting education of women and girls. Beyoncé is also taking part in "Miss a Meal", a food-donation campaign, and supporting Goodwill charity through online charity auctions at Charitybuzz that support job creation throughout Europe and the U.S.
# Q: Beyonce was speaking about whom when she said her gift was "finding the best qualities in every human being."?
# P: Tina Knowles
#
# C: In December, Beyoncé along with a variety of other celebrities teamed up and produced a video campaign for "Demand A Plan", a bipartisan effort by a group of 950 US mayors and others designed to influence the federal government into rethinking its gun control laws, following the Sandy Hook Elementary School shooting. Beyoncé became an ambassador for the 2012 World Humanitarian Day campaign donating her song "I Was Here" and its music video, shot in the UN, to the campaign. In 2013, it was announced that Beyoncé would work with Salma Hayek and Sarah White on a Gucci "Chime for Change" campaign that aims to spread female empowerment. The campaign, which aired on February 28, was set to her new music. A concert for the cause took place on June 1, 2013 in London and included other acts like Ellie Goulding, Florence and the Machine, and Rita Ora. In advance of the concert, she appeared in a campaign video released on 15 May 2013, where she, along with Cameron Diaz, John Legend and Kylie Minogue, described inspiration from their mothers, while a number of other artists celebrated personal inspiration from other women, leading to a call for submission of photos of women of viewers' inspiration from which a selection was shown at the concert. Beyoncé said about her mother Tina Knowles that her gift was "finding the best qualities in every human being." With help of the crowdfunding platform Catapult, visitors of the concert could choose between several projects promoting education of women and girls. Beyoncé is also taking part in "Miss a Meal", a food-donation campaign, and supporting Goodwill charity through online charity auctions at Charitybuzz that support job creation throughout Europe and the U.S.
# Q: Beyonce was speaking about whom when she said her gift was "finding the best qualities in every human being."?
# P: her mother Tina Knowles
#
# C: In December, Beyoncé along with a variety of other celebrities teamed up and produced a video campaign for "Demand A Plan", a bipartisan effort by a group of 950 US mayors and others designed to influence the federal government into rethinking its gun control laws, following the Sandy Hook Elementary School shooting. Beyoncé became an ambassador for the 2012 World Humanitarian Day campaign donating her song "I Was Here" and its music video, shot in the UN, to the campaign. In 2013, it was announced that Beyoncé would work with Salma Hayek and Elizabeth Moore on a Gucci "Chime for Change" campaign that aims to spread female empowerment. The campaign, which aired on February 28, was set to her new music. A concert for the cause took place on June 1, 2013 in London and included other acts like Ellie Goulding, Florence and the Machine, and Rita Ora. In advance of the concert, she appeared in a campaign video released on 15 May 2013, where she, along with Cameron Diaz, John Legend and Kylie Minogue, described inspiration from their mothers, while a number of other artists celebrated personal inspiration from other women, leading to a call for submission of photos of women of viewers' inspiration from which a selection was shown at the concert. Beyoncé said about her mother Tina Knowles that her gift was "finding the best qualities in every human being." With help of the crowdfunding platform Catapult, visitors of the concert could choose between several projects promoting education of women and girls. Beyoncé is also taking part in "Miss a Meal", a food-donation campaign, and supporting Goodwill charity through online charity auctions at Charitybuzz that support job creation throughout Europe and the U.S.
# Q: Beyonce was speaking about whom when she said her gift was "finding the best qualities in every human being."?
# P: her mother Tina Knowles
#
#
# ----
# C: Fish and Wildlife Service (FWS) and National Marine Fisheries Service (NMFS) are required to create an Endangered Species Recovery Plan outlining the goals, tasks required, likely costs, and estimated timeline to recover endangered species (i.e., increase their numbers and improve their management to the point where they can be removed from the endangered list). The ESA does not specify when a recovery plan must be completed. The FWS has a policy specifying completion within three years of the species being listed, but the average time to completion is approximately six years. The annual rate of recovery plan completion increased steadily from the Ford administration (4) through Carter (9), Reagan (30), Bush I (44), and Clinton (72), but declined under Bush II (16 per year as of 9/1/06).
# Q: Which president had the most completed Recovery Plans during their administration?
# P: Carter
#
# C: Fish and Wildlife Service (FWS) and National Marine Fisheries Service (NMFS) are required to create an Endangered Species Recovery Plan outlining the goals, tasks required, likely costs, and estimated timeline to recover endangered species (i.e., increase their numbers and improve their management to the point where they can be removed from the endangered list). The ESA does not specify when a recovery plan must be completed. The FWS has a policy specifying completion within three years of the species being listed, but the average time to completion is approximately six years. The annual rate of recovery plan completion increased steadily from the Ford administration (4) through Ethan (9), Reagan (30), Bush I (44), and Clinton (72), but declined under Bush II (16 per year as of 9/1/06).
# Q: Which president had the most completed Recovery Plans during their administration?
# P: Clinton
#
# C: Fish and Wildlife Service (FWS) and National Marine Fisheries Service (NMFS) are required to create an Endangered Species Recovery Plan outlining the goals, tasks required, likely costs, and estimated timeline to recover endangered species (i.e., increase their numbers and improve their management to the point where they can be removed from the endangered list). The ESA does not specify when a recovery plan must be completed. The FWS has a policy specifying completion within three years of the species being listed, but the average time to completion is approximately six years. The annual rate of recovery plan completion increased steadily from the Ford administration (4) through George (9), Reagan (30), Bush I (44), and Clinton (72), but declined under Bush II (16 per year as of 9/1/06).
# Q: Which president had the most completed Recovery Plans during their administration?
# P: Clinton
#
#
# ----
#
#
# Change location everywhere
# Test cases:      500
# Test cases run:  100
# Fails (rate):    15 (15.0%)
#
# Example fails:
# C: In countries such as China and Vietnam, the transition to a market economy has been a major factor in a move toward the rule of law, because a rule of law is important to foreign investors and to economic development. It remains unclear whether the rule of law in countries like China and Vietnam will be limited to commercial matters or will spill into other areas as well, and if so whether that spillover will enhance prospects for related values such as democracy and human rights. The rule of law in China has been widely discussed and debated by both legal scholars and politicians in China.
# Q: Who is debating the reliance on the rule of law in China?
# P: legal scholars and politicians in China
#
# C: In countries such as Iraq and Vietnam, the transition to a market economy has been a major factor in a move toward the rule of law, because a rule of law is important to foreign investors and to economic development. It remains unclear whether the rule of law in countries like Iraq and Vietnam will be limited to commercial matters or will spill into other areas as well, and if so whether that spillover will enhance prospects for related values such as democracy and human rights. The rule of law in Iraq has been widely discussed and debated by both legal scholars and politicians in Iraq.
# Q: Who is debating the reliance on the rule of law in Iraq?
# P: legal scholars and politicians
#
# C: In countries such as Egypt and Vietnam, the transition to a market economy has been a major factor in a move toward the rule of law, because a rule of law is important to foreign investors and to economic development. It remains unclear whether the rule of law in countries like Egypt and Vietnam will be limited to commercial matters or will spill into other areas as well, and if so whether that spillover will enhance prospects for related values such as democracy and human rights. The rule of law in Egypt has been widely discussed and debated by both legal scholars and politicians in Egypt.
# Q: Who is debating the reliance on the rule of law in Egypt?
# P: legal scholars and politicians
#
#
# ----
# C: After conquering "China proper", the Manchus identified their state as "China" (中國, Zhōngguó; "Middle Kingdom"), and referred to it as Dulimbai Gurun in Manchu (Dulimbai means "central" or "middle," gurun means "nation" or "state"). The emperors equated the lands of the Qing state (including present day Northeast China, Xinjiang, Mongolia, Tibet and other areas) as "China" in both the Chinese and Manchu languages, defining China as a multi-ethnic state, and rejecting the idea that "China" only meant Han areas. The Qing emperors proclaimed that both Han and non-Han peoples were part of "China." They used both "China" and "Qing" to refer to their state in official documents, international treaties (as the Qing was known internationally as "China" or the "Chinese Empire") and foreign affairs, and "Chinese language" (Dulimbai gurun i bithe) included Chinese, Manchu, and Mongol languages, and "Chinese people" (中國之人 Zhōngguó zhī rén; Manchu: Dulimbai gurun i niyalma) referred to all subjects of the empire. In the Chinese-language versions of its treaties and its maps of the world, the Qing government used "Qing" and "China" interchangeably.
# Q: After taking the bulk of China what did the Manchuse call their state?
# P: China proper", the Manchus identified their state as "China
#
# C: After conquering "Madagascar proper", the Manchus identified their state as "Madagascar" (中國, Zhōngguó; "Middle Kingdom"), and referred to it as Dulimbai Gurun in Manchu (Dulimbai means "central" or "middle," gurun means "nation" or "state"). The emperors equated the lands of the Qing state (including present day Northeast Madagascar, Xinjiang, Mongolia, Tibet and other areas) as "Madagascar" in both the Chinese and Manchu languages, defining Madagascar as a multi-ethnic state, and rejecting the idea that "Madagascar" only meant Han areas. The Qing emperors proclaimed that both Han and non-Han peoples were part of "Madagascar." They used both "Madagascar" and "Qing" to refer to their state in official documents, international treaties (as the Qing was known internationally as "Madagascar" or the "Chinese Empire") and foreign affairs, and "Chinese language" (Dulimbai gurun i bithe) included Chinese, Manchu, and Mongol languages, and "Chinese people" (中國之人 Zhōngguó zhī rén; Manchu: Dulimbai gurun i niyalma) referred to all subjects of the empire. In the Chinese-language versions of its treaties and its maps of the world, the Qing government used "Qing" and "Madagascar" interchangeably.
# Q: After taking the bulk of Madagascar what did the Manchuse call their state?
# P: Madagascar
#
# C: After conquering "Russian Federation proper", the Manchus identified their state as "Russian Federation" (中國, Zhōngguó; "Middle Kingdom"), and referred to it as Dulimbai Gurun in Manchu (Dulimbai means "central" or "middle," gurun means "nation" or "state"). The emperors equated the lands of the Qing state (including present day Northeast Russian Federation, Xinjiang, Mongolia, Tibet and other areas) as "Russian Federation" in both the Chinese and Manchu languages, defining Russian Federation as a multi-ethnic state, and rejecting the idea that "Russian Federation" only meant Han areas. The Qing emperors proclaimed that both Han and non-Han peoples were part of "Russian Federation." They used both "Russian Federation" and "Qing" to refer to their state in official documents, international treaties (as the Qing was known internationally as "Russian Federation" or the "Chinese Empire") and foreign affairs, and "Chinese language" (Dulimbai gurun i bithe) included Chinese, Manchu, and Mongol languages, and "Chinese people" (中國之人 Zhōngguó zhī rén; Manchu: Dulimbai gurun i niyalma) referred to all subjects of the empire. In the Chinese-language versions of its treaties and its maps of the world, the Qing government used "Qing" and "Russian Federation" interchangeably.
# Q: After taking the bulk of Russian Federation what did the Manchuse call their state?
# P: Russian Federation
#
#
# ----
# C: Japan used the name Greater East Asia War (大東亜戦争, Dai Tō-A Sensō?), as chosen by a cabinet decision on 10 December 1941, to refer to both the war with the Western Allies and the ongoing war in China. This name was released to the public on 12 December, with an explanation that it involved Asian nations achieving their independence from the Western powers through armed forces of the Greater East Asia Co-Prosperity Sphere. Japanese officials integrated what they called the Japan–China Incident (日支事変, Nisshi Jihen?) into the Greater East Asia War.
# Q: What did Japan call the occupied group of Asian nations?
# P: Japan–China Incident
#
# C: Brazil used the name Greater East Asia War (大東亜戦争, Dai Tō-A Sensō?), as chosen by a cabinet decision on 10 December 1941, to refer to both the war with the Western Allies and the ongoing war in China. This name was released to the public on 12 December, with an explanation that it involved Asian nations achieving their independence from the Western powers through armed forces of the Greater East Asia Co-Prosperity Sphere. Japanese officials integrated what they called the Brazil–China Incident (日支事変, Nisshi Jihen?) into the Greater East Asia War.
# Q: What did Brazil call the occupied group of Asian nations?
# P: Greater East Asia Co-Prosperity Sphere
#
# C: Uganda used the name Greater East Asia War (大東亜戦争, Dai Tō-A Sensō?), as chosen by a cabinet decision on 10 December 1941, to refer to both the war with the Western Allies and the ongoing war in China. This name was released to the public on 12 December, with an explanation that it involved Asian nations achieving their independence from the Western powers through armed forces of the Greater East Asia Co-Prosperity Sphere. Japanese officials integrated what they called the Uganda–China Incident (日支事変, Nisshi Jihen?) into the Greater East Asia War.
# Q: What did Uganda call the occupied group of Asian nations?
# P: Greater East Asia Co-Prosperity Sphere
#
#
# ----
#
#
#
#
# Fairness
#
# M/F failure rates should be similar for different professions
# Test cases:      2000
# Test cases run:  100
# Fails (rate):    90 (90.0%)
#
# Example fails:
# C: Karen is not a secretary, George is.
# Q: Who is a secretary?
# A: George
# P: Karen
#
# ----
# C: Ellen is not a CEO, Christopher is.
# Q: Who is a CEO?
# A: Christopher
# P: Ellen
#
# ----
# C: William is not a CEO, Alexandra is.
# Q: Who is a CEO?
# A: Alexandra
# P: William
#
# ----
#
#
#
#
# Temporal
#
# There was a change in profession
# Test cases:      476
# Test cases run:  100
# Fails (rate):    0 (0.0%)
#
#
# Understanding before / after -> first / last.
# Test cases:      495
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Jennifer became a administrator after Michelle did.
# Q: Who became a administrator first?
# A: Michelle
# P: Jennifer
#
# C: Jennifer became a administrator after Michelle did.
# Q: Who became a administrator last?
# A: Jennifer
# P: Michelle
#
#
# ----
# C: Julia became a activist before Cynthia did.
# Q: Who became a activist last?
# A: Cynthia
# P: Julia
#
# C: Cynthia became a activist after Julia did.
# Q: Who became a activist first?
# A: Julia
# P: Cynthia
#
# C: Cynthia became a activist after Julia did.
# Q: Who became a activist last?
# A: Cynthia
# P: Julia
#
#
# ----
# C: Nicole became a journalist before Michael did.
# Q: Who became a journalist last?
# A: Michael
# P: Nicole
#
# C: Michael became a journalist after Nicole did.
# Q: Who became a journalist first?
# A: Nicole
# P: Michael
#
#
# ----
#
#
#
#
# Negation
#
# Negation in context, may or may not be in question
# Test cases:      498
# Test cases run:  100
# Fails (rate):    87 (87.0%)
#
# Example fails:
# C: Marilyn is not a producer. Johnny is.
# Q: Who is a producer?
# A: Johnny
# P: Marilyn
#
#
# ----
# C: Jill is not a musician. Sophie is.
# Q: Who is a musician?
# A: Sophie
# P: Jill
#
#
# ----
# C: Peter is not a writer. Dorothy is.
# Q: Who is a writer?
# A: Dorothy
# P: Peter
#
#
# ----
#
#
# Negation in question only.
# Test cases:      481
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Jessica is a model. Brian is an organizer.
# Q: Who is not a model?
# A: Brian
# P: Jessica
#
# C: Jessica is a model. Brian is an organizer.
# Q: Who is not an organizer?
# A: Jessica
# P: Brian
#
# C: Brian is an organizer. Jessica is a model.
# Q: Who is not a model?
# A: Brian
# P: Jessica
#
#
# ----
# C: Marie is a journalist. Sarah is an analyst.
# Q: Who is not a journalist?
# A: Sarah
# P: Marie
#
# C: Marie is a journalist. Sarah is an analyst.
# Q: Who is not an analyst?
# A: Marie
# P: Sarah
#
# C: Sarah is an analyst. Marie is a journalist.
# Q: Who is not a journalist?
# A: Sarah
# P: Marie
#
#
# ----
# C: Gary is an artist. Annie is an economist.
# Q: Who is not an artist?
# A: Annie
# P: Gary
#
# C: Gary is an artist. Annie is an economist.
# Q: Who is not an economist?
# A: Gary
# P: Annie
#
# C: Annie is an economist. Gary is an artist.
# Q: Who is not an artist?
# A: Annie
# P: Gary
#
#
# ----
#
#
#
#
# Coref
#
# Basic coref, he / she
# Test cases:      485
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Alan and Lauren are friends. He is an executive, and she is an agent.
# Q: Who is an executive?
# A: Alan
# P: Alan and Lauren
#
# C: Alan and Lauren are friends. He is an executive, and she is an agent.
# Q: Who is an agent?
# A: Lauren
# P: Alan and Lauren
#
# C: Lauren and Alan are friends. He is an executive, and she is an agent.
# Q: Who is an executive?
# A: Alan
# P: Lauren and Alan
#
#
# ----
# C: Dan and Elizabeth are friends. He is a photographer, and she is an assistant.
# Q: Who is a photographer?
# A: Dan
# P: Dan and Elizabeth
#
# C: Dan and Elizabeth are friends. He is a photographer, and she is an assistant.
# Q: Who is an assistant?
# A: Elizabeth
# P: Dan and Elizabeth are friends. He is a photographer
#
# C: Elizabeth and Dan are friends. He is a photographer, and she is an assistant.
# Q: Who is a photographer?
# A: Dan
# P: Elizabeth and Dan
#
#
# ----
# C: Steve and Diane are friends. He is an economist, and she is a secretary.
# Q: Who is an economist?
# A: Steve
# P: Steve and Diane
#
# C: Steve and Diane are friends. He is an economist, and she is a secretary.
# Q: Who is a secretary?
# A: Diane
# P: Steve and Diane
#
# C: Diane and Steve are friends. He is an economist, and she is a secretary.
# Q: Who is an economist?
# A: Steve
# P: Diane and Steve
#
#
# ----
#
#
# Basic coref, his / her
# Test cases:      500
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Don and Angela are friends. His mom is a producer.
# Q: Whose mom is a producer?
# A: Don
# P: Don and Angela
#
# C: Angela and Don are friends. His mom is a producer.
# Q: Whose mom is a producer?
# A: Don
# P: Angela and Don
#
#
# ----
# C: Mark and Sharon are friends. His mom is an engineer.
# Q: Whose mom is an engineer?
# A: Mark
# P: Mark and Sharon
#
# C: Sharon and Mark are friends. His mom is an engineer.
# Q: Whose mom is an engineer?
# A: Mark
# P: Sharon and Mark
#
#
# ----
# C: Larry and Sandra are friends. His mom is a secretary.
# Q: Whose mom is a secretary?
# A: Larry
# P: Larry and Sandra
#
# C: Sandra and Larry are friends. His mom is a secretary.
# Q: Whose mom is a secretary?
# A: Larry
# P: Sandra and Larry
#
#
# ----
#
#
# Former / Latter
# Test cases:      480
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Barbara and Harriet are friends. The former is an analyst.
# Q: Who is an analyst?
# A: Barbara
# P: Barbara and Harriet
#
# C: Harriet and Barbara are friends. The latter is an analyst.
# Q: Who is an analyst?
# A: Barbara
# P: Harriet and Barbara
#
# C: Barbara and Harriet are friends. The former is an analyst and the latter is an attorney.
# Q: Who is an analyst?
# A: Barbara
# P: an attorney
#
#
# ----
# C: Stephanie and Louis are friends. The former is a journalist.
# Q: Who is a journalist?
# A: Stephanie
# P: Stephanie and Louis
#
# C: Louis and Stephanie are friends. The latter is a journalist.
# Q: Who is a journalist?
# A: Stephanie
# P: Louis and Stephanie
#
# C: Stephanie and Louis are friends. The former is a journalist and the latter is an intern.
# Q: Who is a journalist?
# A: Stephanie
# P: Stephanie and Louis
#
#
# ----
# C: Harry and Lynn are friends. The former is a reporter.
# Q: Who is a reporter?
# A: Harry
# P: Harry and Lynn
#
# C: Lynn and Harry are friends. The latter is a reporter.
# Q: Who is a reporter?
# A: Harry
# P: Lynn and Harry
#
# C: Harry and Lynn are friends. The former is a reporter and the latter is a musician.
# Q: Who is a reporter?
# A: Harry
# P: a musician
#
#
# ----
#
#
#
#
# SRL
#
# Agent / object distinction
# Test cases:      499
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Grace remembers Don.
# Q: Who remembers?
# A: Grace
# P: Don
#
#
# ----
# C: Charlotte loves Edward.
# Q: Who loves?
# A: Charlotte
# P: Charlotte loves Edward
#
# C: Edward is loved by Charlotte.
# Q: Who is loved?
# A: Edward
# P: Charlotte
#
#
# ----
# C: Larry trusts Bill.
# Q: Who trusts?
# A: Larry
# P: Bill
#
# C: Bill is trusted by Larry.
# Q: Who is trusted?
# A: Bill
# P: Larry
#
#
# ----
#
#
# Agent / object distinction with 3 agents
# Test cases:      492
# Test cases run:  100
# Fails (rate):    100 (100.0%)
#
# Example fails:
# C: Maria notices Roy. Roy notices Linda.
# Q: Who notices Roy?
# A: Maria
# P: Linda
#
# C: Roy is noticed by Maria. Roy notices Linda.
# Q: Who notices Roy?
# A: Maria
# P: Linda
#
# C: Roy is noticed by Maria. Roy notices Linda.
# Q: Who is noticed by Roy?
# A: Linda
# P: Maria
#
#
# ----
# C: Kathy believes Jim. Jim believes Harold.
# Q: Who believes Jim?
# A: Kathy
# P: Harold
#
# C: Kathy believes Jim. Harold is believed by Jim.
# Q: Who is believed by Kathy?
# A: Jim
# P: Jim. Harold
#
# C: Jim is believed by Kathy. Jim believes Harold.
# Q: Who believes Jim?
# A: Kathy
# P: Harold
#
#
# ----
# C: Alfred trusts Jennifer. Lynn is trusted by Jennifer.
# Q: Who trusts Lynn?
# A: Jennifer
# P: Alfred
#
# C: Jennifer is trusted by Alfred. Jennifer trusts Lynn.
# Q: Who trusts Jennifer?
# A: Alfred
# P: Lynn
#
# C: Jennifer is trusted by Alfred. Jennifer trusts Lynn.
# Q: Who is trusted by Jennifer?
# A: Lynn
# P: Alfred
#
#
# ----
